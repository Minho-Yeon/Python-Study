# %%
import numpy as np
import pandas as pd
from pandas import DataFrame,Series
import matplotlib.pyplot as plt
import seaborn as sns

# %%
arr1 = np.random.randn(3,3)
print(arr1)
# Out:
# [[-1.13780771 -0.7417411  -1.04180668]
#  [-0.12930793  0.04799718 -0.78794054]
#  [ 0.355998    0.09403148  0.7962439 ]]

# %%
print(np.ndim(arr1))
print(arr1.ndim)
print(arr1.shape)
print(np.shape(arr1))
# Out:
# 2
# 2
# (3, 3)
# (3, 3)

# %%
ser1 = Series(np.random.randn(4), index=list('abcd'),name = "test")
ser1.index.name = 'gubun'
# ser1.name = 'testData'
print(ser1)
# Out:
# gubun
# a   -0.851626
# b    0.329189
# c    0.005296
# d   -0.823132
# Name: test, dtype: float64

# %%
#생성...
data1 = {'city':['seoul','pusan','icheon','daejeon'],
        'pop':[1.9,1.2,0.2,0.7],'info':['서울','부산','이천','대전']}
df1 = DataFrame(data1, index=list('abcd'))
df1
# Out:
#       city  pop info
# a    seoul  1.9   서울
# b    pusan  1.2   부산
# c   icheon  0.2   이천
# d  daejeon  0.7   대전

# %%
#생성...
data2 = {'city':['seoul','pusan','icheon','daejeon'],
        'x2':[1.9,1.2,0.2,0.7],'x3':['서울','부산','이천','대전']}
df2 = DataFrame(data2, index=list('bcde'))
df2
# Out:
#       city   x2  x3
# b    seoul  1.9  서울
# c    pusan  1.2  부산
# d   icheon  0.2  이천
# e  daejeon  0.7  대전

# %%
#merge how="inner"의 경우에 키가 같은 값을 가지는 값만 merge(교집합)
#how="outer"는 같지않은 키도 값을 비워놓고 merge (합집합)
df_all = pd.merge(df1,df2,on='city',how='inner')
df_all
# Out:
#       city  pop info   x2  x3
# 0    seoul  1.9   서울  1.9  서울
# 1    pusan  1.2   부산  1.2  부산
# 2   icheon  0.2   이천  0.2  이천
# 3  daejeon  0.7   대전  0.7  대전

# %%
# print(df1.index)
# print(df1.columns)
# print(df1.values)
df1.index.name ="gubun"
df1.columns.name = 'cityInfo'
print(df1.dtypes)
df1['x']=[2.5, 1.8, np.nan, 0.9]
df1
# Out:
# cityInfo
# city     object
# pop     float64
# info     object
# dtype: object
# cityInfo     city  pop info    x
# gubun
# a           seoul  1.9   서울  2.5
# b           pusan  1.2   부산  1.8
# c          icheon  0.2   이천  NaN
# d         daejeon  0.7   대전  0.9

# %%
# df1_res=df1.rename(columns={df1.columns[3]:'size'})
# df1_res
df1.rename(columns = {'x':'size'},inplace=True)
print(df1['city'])
print()
print(df1[0:2])
# Out:
# gubun
# a      seoul
# b      pusan
# c     icheon
# d    daejeon
# Name: city, dtype: object
#
# cityInfo   city  pop info  size
# gubun
# a         seoul  1.9   서울   2.5
# b         pusan  1.2   부산   1.8

# %%
df2 = DataFrame(np.random.randint(50,100,16).reshape(4,4),columns=['x1','x2','x3','x4'],index=list('edfg'))
df2
# Out:
#    x1  x2  x3  x4
# e  62  95  51  57
# d  99  59  52  62
# f  51  94  51  95
# g  57  62  93  92

# %%
dfTips = pd.read_csv('../data/tips1.csv')
dfTips
dfTips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 7 columns):
# total_bill    245 non-null float64
# tip           244 non-null float64
# sex           244 non-null object
# smoker        244 non-null object
# day           244 non-null object
# time          244 non-null object
# size          244 non-null float64
# dtypes: float64(3), object(4)
# memory usage: 13.5+ KB

# %%
dfSemi = pd.read_csv('../semi_data/trainset.csv')
dfSemi
dfSemi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2496 entries, 0 to 2495
# Columns: 1485 entries, Unnamed: 0 to Y
# dtypes: float64(861), int64(2), object(622)
# memory usage: 28.3+ MB

# %%
# df1.head(2)
# df1.tail(2)
df1
# Out:
# cityInfo     city  pop info  size
# gubun
# a           seoul  1.9   서울   2.5
# b           pusan  1.2   부산   1.8
# c          icheon  0.2   이천   NaN
# d         daejeon  0.7   대전   0.9

# %%
# df1.sort_index(ascending=True,axis=1)
df1.sort_values(by=["size",'pop'],ascending=[True,False])
# Out:
# cityInfo     city  pop info  size
# gubun
# d         daejeon  0.7   대전   0.9
# b           pusan  1.2   부산   1.8
# a           seoul  1.9   서울   2.5
# c          icheon  0.2   이천   NaN

# %%
df1['pop'].sort_values(ascending=False).plot(kind='bar')

# %%
df1
# Out:
# cityInfo     city  pop info  size
# gubun
# a           seoul  1.9   서울   2.5
# b           pusan  1.2   부산   1.8
# c          icheon  0.2   이천   NaN
# d         daejeon  0.7   대전   0.9

# %%
# df1.iloc[1:,0:2]
# df1.loc['b':'c','pop':]
# df1.at['b','pop']
# df1.iat[1,1]
# df1['pop'][0]
# Out:
# 1.9

# %%
# df1.iloc[1:,0:2]
# df1.at['b','size']=np.nan
# df1.loc['e']=np.nan
# df1['sss']=np.nan
# df1=df1.loc['a':'e','city':'size']

# %%
df1.dtypes
# Out:
# cityInfo
# city     object
# pop     float64
# info     object
# size    float64
# dtype: object

# %%
dfT = df1.T
print(dfT)
print(dfT.dtypes)
# Out:
# gubun         a      b       c        d    e
# cityInfo
# city      seoul  pusan  icheon  daejeon  NaN
# pop         1.9    1.2     0.2      0.7  NaN
# info         서울     부산      이천       대전  NaN
# size        2.5    NaN     NaN      0.9  NaN
# gubun
# a    object
# b    object
# c    object
# d    object
# e    object
# dtype: object

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %%
df1
# Out:
# cityInfo     city  pop info  size
# gubun
# a           seoul  1.9   서울   2.5
# b           pusan  1.2   부산   NaN
# c          icheon  0.2   이천   NaN
# d         daejeon  0.7   대전   0.9
# e             NaN  NaN  NaN   NaN

# %%
df1[df1['info'].isin(['서울'])]
# Out:
# cityInfo   city  pop info  size
# gubun
# a         seoul  1.9   서울   2.5

# %%
dir(df1['info'])
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
# ...

# %%
df1_ori=df1.copy()
df1_ori
# Out:
# cityInfo     city  pop info  size
# gubun
# a           seoul  1.9   서울   2.5
# b           pusan  1.2   부산   1.8
# c          icheon  0.2   이천   NaN
# d         daejeon  0.7   대전   0.9

# %%
# del df1['size']
# df1=df1_ori.copy()
df1.at['c','info']=np.nan
df1.at['b','pop']=np.nan
df1.at['d','size']=np.nan
df1.at['b','size']=np.nan
df1.loc['e']=np.nan
df1
# Out:
# cityInfo     city  pop info  size
# gubun
# a           seoul  1.9   서울   2.5
# b           pusan  NaN   부산   NaN
# c          icheon  0.2  NaN   NaN
# d         daejeon  0.7   대전   NaN
# e             NaN  NaN  NaN   NaN

# %%
df1.isna().sum(axis=1)
# Out:
# gubun
# a    0
# b    2
# c    2
# d    1
# e    4
# dtype: int64

# %%
dfSemi.isna().sum(axis=1)
# Out:
# 0       226
# 1       197
# 2       226
# 3       225
# 4       196
#        ...
# 2491    233
# 2492    254
# 2493    246
# 2494    238
# 2495    228
# Length: 2496, dtype: int64

# %%
dfSemi.notnull().sum(axis=1).hist(bins=100)

# %%
dfSemi.notnull().sum(axis=1).plot(kind='hist',bins=50,grid=True)

# %%
df1.dropna(axis=1,thresh=3)
# Out:
# cityInfo     city  pop info
# gubun
# a           seoul  1.9   서울
# b           pusan  NaN   부산
# c          icheon  0.2  NaN
# d         daejeon  0.7   대전
# e             NaN  NaN  NaN

# %%
df1
# Out:
# cityInfo     city  pop info  size
# gubun
# a           seoul  1.9   서울   2.5
# b           pusan  NaN   부산   NaN
# c          icheon  0.2  NaN   NaN
# d         daejeon  0.7   대전   NaN
# e             NaN  NaN  NaN   NaN

# %%
#fillna 메소드는 값이 없을 경우 앞 뒤 값의 평균 값으로 대체함
# df1.fillna(df1.mean())

# bfill은 값이 없으면 뒤에 값을 가져옴
# df1.fillna(method='bfill')

#ffill은 값이 없으면 앞에 값을 가져옴
#df1.fillna(method='ffill')

#mean은 axis=0을 기준으로 평균값을 계산하는 메소드. skipna=True이면 NaN 값은 건너뛰고 평균값을 계산
# df1.mean(axis=0,skipna=True)
# Out:
# cityInfo
# pop     0.933333
# size    2.500000
# dtype: float64
