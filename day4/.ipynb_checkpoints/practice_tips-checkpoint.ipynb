# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
#해당 파일을 읽어 df를 생성하세요

tipdf= pd.read_csv('../data/tips1.csv')
tipdf
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner   2.0
# 1         10.34  1.66    Male     No   Sun  Dinner   3.0
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0
# 3         23.68  3.31    Male     No   Sun  Dinner   2.0
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0
# ..          ...   ...     ...    ...   ...     ...   ...
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
# 244       25.34   NaN     NaN    NaN   NaN     NaN   NaN
#
# [245 rows x 7 columns]

# %%
#tipdf의 차원을 조회하세요
np.ndim(tipdf)
# Out:
# 2

# %%
#tipdf의 크기를 조회하세요(행, 열)
np.shape(tipdf)
# Out:
# (245, 7)

# %%
#맨 마지막 데이터 3개을 조회하세요
tipdf.tail(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
# 244       25.34   NaN     NaN    NaN   NaN     NaN   NaN

# %%
#df의 정보를 조회하세요
tipdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 7 columns):
# total_bill    245 non-null float64
# tip           244 non-null float64
# sex           244 non-null object
# smoker        244 non-null object
# day           244 non-null object
# time          244 non-null object
# size          244 non-null float64
# dtypes: float64(3), object(4)
# memory usage: 13.5+ KB

# %%
#가장 팁이 높은 데이터 3개의 정보를 구하세요
tipdf.sort_values('tip',ascending=False).head(3)
# Out:
#      total_bill    tip   sex smoker  day    time  size
# 170       50.81  10.00  Male    Yes  Sat  Dinner   3.0
# 212       48.33   9.00  Male     No  Sat  Dinner   4.0
# 23        39.42   7.58  Male     No  Sat  Dinner   4.0

# %%
#tips_pct를 구해서 tipdf에 새로운 컬럼명으로 추가하세요 
tipdf['tips_pct']=round(tipdf['tip']/tipdf['total_bill']*100,2)
tipdf
# Out:
#      total_bill   tip     sex smoker   day    time  size  tips_pct
# 0         16.99  1.01  Female     No   Sun  Dinner   2.0      5.94
# 1         10.34  1.66    Male     No   Sun  Dinner   3.0     16.05
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0     16.66
# 3         23.68  3.31    Male     No   Sun  Dinner   2.0     13.98
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0     14.68
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0      7.36
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0      8.82
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0      9.82
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0     15.97
# 244       25.34   NaN     NaN    NaN   NaN     NaN   NaN       NaN
#
# [245 rows x 8 columns]

# %%
#성별, 팁비율별로 정렬하여 팁 비율이 높은 정보 3개 출력

tipdf.sort_values(['sex','tips_pct'],ascending=[False,False]).head(3)
# Out:
#      total_bill   tip   sex smoker  day    time  size  tips_pct
# 172        7.25  5.15  Male    Yes  Sun  Dinner   2.0     71.03
# 232       11.61  3.39  Male     No  Sat  Dinner   2.0     29.20
# 183       23.17  6.50  Male    Yes  Sun  Dinner   4.0     28.05

# %%
#male 정보를 따로 분리해서 크기 정보 조회
tipdf[tipdf['sex']=='Male'].shape
tipdf[tipdf['sex'].isin(['Male'])].shape
# Out:
# (157, 8)

# %%
#Female 정보를 따로 분리해서 크기 정보 조회
tipdf[tipdf['sex']=='Female'].shape
# Out:
# (87, 8)

# %%
#각 row별 na값 갯수 count
tipdf.isna().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 240    0
# 241    0
# 242    0
# 243    0
# 244    7
# Length: 245, dtype: int64

# %%
#na값 포함된 row 삭제 
tipdf.dropna()
#dropna는 기본적으로 axis=0이다.
# Out:
#      total_bill   tip     sex smoker   day    time  size  tips_pct
# 0         16.99  1.01  Female     No   Sun  Dinner   2.0      5.94
# 1         10.34  1.66    Male     No   Sun  Dinner   3.0     16.05
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0     16.66
# 3         23.68  3.31    Male     No   Sun  Dinner   2.0     13.98
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0     14.68
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner   3.0     20.39
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0      7.36
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0      8.82
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0      9.82
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0     15.97
#
# [244 rows x 8 columns]

# %%
tipdf['tips_pct'].plot(kind='hist',bins=50)
plt.show()

# %%
#데이터를 정리해서 보여줌 
tipdf.describe()
# Out:
#        total_bill         tip        size    tips_pct
# count  245.000000  244.000000  244.000000  244.000000
# mean    19.808612    2.998279    2.569672   16.079754
# std      8.891234    1.383638    0.951100    6.107020
# min      3.070000    1.000000    1.000000    3.560000
# 25%     13.370000    2.000000    2.000000   12.910000
# 50%     17.810000    2.900000    2.000000   15.475000
# 75%     24.270000    3.562500    3.000000   19.147500
# max     50.810000   10.000000    6.000000   71.030000

# %%
tipdf['tips_pct'].quantile([0.1, 0.4, 0.9])
# Out:
# 0.1     9.856
# 0.4    14.662
# 0.9    21.724
# Name: tips_pct, dtype: float64

# %%
def get_tippct(df):
    return round(df['tip']/df['total_bill']*100,2)

# %%
df4= DataFrame(np.random.randint(10,15,16).reshape(4,4),columns=list('abcd'),index=list("edfg"))
df4
# Out:
#     a   b   c   d
# e  10  11  14  13
# d  11  14  14  10
# f  10  13  10  10
# g  13  12  13  11

# %%
# df4.apply(lambda i:i.max()-i.min())
df4.apply(np.cumsum)
# Out:
#     a   b   c   d
# e  10  21  35  48
# d  11  25  39  49
# f  10  23  33  43
# g  13  25  38  49
